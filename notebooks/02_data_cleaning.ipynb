# %%
import pandas as pd

df = pd.read_csv("../data/raw/stray_animal_reports.csv")

df.head()
# Out:
#    Report_ID Animal_Type                Breed  Age  Gender Health_Status  \
# 0          1         Dog               Beagle    5    Male       Healthy
# 1          2         Dog             Labrador   15  Female       Healthy
# 2          3         Cat  Domestic Short Hair    5    Male       Healthy
# 3          4         Dog     Golden Retriever    1    Male      Critical
# 4          5         Dog               Beagle    5    Male          Sick
#
#   Location Reported_Date    Rescue_Status
# 0  Negombo    2026-01-13          Rescued
# 1    Galle    2026-01-28          Rescued
# 2  Colombo    2026-05-22          Rescued
# 3   Jaffna    2026-04-29         Released
# 4  Colombo    2026-01-27  Under Treatment

# %%
df.isnull().sum()
# Out:
# Report_ID        0
# Animal_Type      0
# Breed            0
# Age              0
# Gender           0
# Health_Status    0
# Location         0
# Reported_Date    0
# Rescue_Status    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
duplicate_count = df.duplicated().sum()

print("Number of duplicate records:", duplicate_count)
# Out:
# Number of duplicate records: 0

# %%
df.drop_duplicates(inplace=True)

# %%
df.drop_duplicates(inplace=True)

print("Dataset shape after removing duplicates:", df.shape)
# Out:
# Dataset shape after removing duplicates: (1000, 9)

# %%
df["Reported_Date"] = pd.to_datetime(df["Reported_Date"])

# %%
df["Reported_Date"].dtype
# Out:
# dtype('<M8[ns]')

# %%
df["Age"].describe()
# Out:
# count    1000.000000
# mean        8.071000
# std         4.313765
# min         1.000000
# 25%         5.000000
# 50%         8.000000
# 75%        12.000000
# max        15.000000
# Name: Age, dtype: float64

# %%
df["Age"].dtype
# Out:
# dtype('int64')

# %%
(df["Age"] < 0).sum()
# Out:
# np.int64(0)

# %%
print("Animal Types:")
print(df["Animal_Type"].unique())
# Out:
# Animal Types:
# ['Dog' 'Cat']

# %%
print("Health Statuses:")
print(df["Health_Status"].unique())
# Out:
# Health Statuses:
# ['Healthy' 'Critical' 'Sick' 'Injured']

# %%
print("Rescue Statuses:")
print(df["Rescue_Status"].unique())
# Out:
# Rescue Statuses:
# ['Rescued' 'Released' 'Under Treatment' 'Pending']

# %%
print("Genders:")
print(df["Gender"].unique())
# Out:
# Genders:
# ['Male' 'Female']

# %%
print("Locations:")
print(df["Location"].unique())
# Out:
# Locations:
# ['Negombo' 'Galle' 'Colombo' 'Jaffna' 'Batticaloa' 'Matara' 'Kurunegala'
#  'Anuradhapura' 'Kandy' 'Ratnapura']

# %%
df["Animal_Type"] = df["Animal_Type"].str.strip()
df["Breed"] = df["Breed"].str.strip()
df["Gender"] = df["Gender"].str.strip()
df["Health_Status"] = df["Health_Status"].str.strip()
df["Location"] = df["Location"].str.strip()
df["Rescue_Status"] = df["Rescue_Status"].str.strip()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Report_ID      1000 non-null   int64
#  1   Animal_Type    1000 non-null   object
#  2   Breed          1000 non-null   object
#  3   Age            1000 non-null   int64
#  4   Gender         1000 non-null   object
#  5   Health_Status  1000 non-null   object
#  6   Location       1000 non-null   object
#  7   Reported_Date  1000 non-null   datetime64[ns]
#  8   Rescue_Status  1000 non-null   object
# dtypes: datetime64[ns](1), int64(2), object(6)
# memory usage: 70.4+ KB

# %%
df.isnull().sum()
# Out:
# Report_ID        0
# Animal_Type      0
# Breed            0
# Age              0
# Gender           0
# Health_Status    0
# Location         0
# Reported_Date    0
# Rescue_Status    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.to_csv(
    "../data/processed/cleaned_stray_animal_reports.csv",
    index=False
)

# %%
df["Animal_Type"].unique()
# Out:
# array(['Dog', 'Cat'], dtype=object)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["Health_Status"].unique()
# Out:
# array(['Healthy', 'Critical', 'Sick', 'Injured'], dtype=object)

# %%
df["Rescue_Status"].unique()
# Out:
# array(['Rescued', 'Released', 'Under Treatment', 'Pending'], dtype=object)

# %%
df["Gender"].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df["Location"].unique()
# Out:
# array(['Negombo', 'Galle', 'Colombo', 'Jaffna', 'Batticaloa', 'Matara',
#        'Kurunegala', 'Anuradhapura', 'Kandy', 'Ratnapura'], dtype=object)
